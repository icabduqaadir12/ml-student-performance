# %%
import pandas as pd

# %%
data = pd.read_csv("../data/student_data_cleaned.csv")

# %%
data['guardian']
# Out:
# 0      mother
# 1      father
# 2      mother
# 3      mother
# 4      father
#         ...
# 390     other
# 391    mother
# 392     other
# 393    mother
# 394    father
# Name: guardian, Length: 395, dtype: object

# %%
data.shape
# Out:
# (395, 33)

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [raw]
# ## Target Variable Selection
#
# The target variable chosen is **G3**, which represents the student's final grade.
# This is the most meaningful outcome to predict because it summarizes overall
# academic performance at the end of the course.

# %%
X = data.drop(columns=['G3'])   ## Seperate Features

# %%
Y = data["G3"]

# %%
X.shape
# Out:
# (395, 32)

# %%
X.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# dtype: object

# %%
X_encoded = pd.get_dummies(X, drop_first=True)

# %%
X_encoded
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  ...  guardian_mother  guardian_other  schoolsup_yes  \
# ...

# %% [raw]
# # Categorical variables were encoded using one-hot encoding
# # because machine learning models require numeric input.

# %%
X_encoded.isnull().sum().sum()
# Out:
# 0

# %%
X_encoded.shape, y.shape
# Out:
# ((395, 41), (395,))

# %%
# This dataset is ML-ready
